# %%
library(ggplot2)

# %%
pl = ggplot(data = mtcars, aes(x=mpg, y=hp))
pl + geom_point() + facet_grid(cyl ~ .) + stat_smooth() + coord_cartesian(xlim = c(15,25)) + theme_bw()
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %% [markdown]
# # Histogram

# %%
library(ggplot2movies)

# %%
colnames(movies)
# Out:
#  [1] "title"       "year"        "length"      "budget"      "rating"
#  [6] "votes"       "r1"          "r2"          "r3"          "r4"
# [11] "r5"          "r6"          "r7"          "r8"          "r9"
# [16] "r10"         "mpaa"        "Action"      "Animation"   "Comedy"
# [21] "Drama"       "Documentary" "Romance"     "Short"

# %%
pl = ggplot(movies, aes(x=rating))
pl2 = pl + geom_histogram(binwidth = 0.5, aes(fill=..count..)) 
pl3 = pl2 + xlab('Movie rating') + ylab('Count')
pl4 = pl3 + ggtitle("Histogram of Movie Rating")
pl4 + labs(subtitle = 'Tam Huynh', caption = 'Data Source: Movies')
# Out:
# plot without title

# %% [markdown]
# # Scatterplot

# %%
df = mtcars
pl = ggplot(df, aes(x= wt, y = mpg))
pl + geom_point(aes(shape =  factor(cyl), col = factor(cyl)),size = 5)
# Out:
# plot without title

# %%
df = mtcars
pl1 = ggplot(df, aes(x= wt, y = mpg))
pl2 = pl1 + geom_point(aes(color=hp), size = 5)
pl3 = pl2 + scale_color_gradient(low = 'blue', high = 'red')
pl3
# Out:
# plot without title

# %% [markdown]
# # Barplot

# %%
df = mpg

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
pl1 = ggplot(mpg, aes(x = class))
pl2 = pl1 + geom_bar(aes(fill = drv), position = "dodge") #Show the count
pl2
# Out:
# plot without title

# %%
pl1 + geom_bar(aes(fill = drv), position = "fill") #Show the percentage
# Out:
# plot without title

# %% [markdown]
# # Boxplot

# %%
df = mtcars

# %%
pl1 = ggplot(df, aes(x = factor(cyl), y = mpg))
pl2 = pl1 + geom_boxplot(aes(fill = factor(cyl))) + theme_dark()
pl2
# Out:
# plot without title

# %% [markdown]
# # 2 Variable Plotting with ggplot2

# %%
pl1 =  ggplot(movies, aes(x=year, y=rating))
pl2 = pl1 + geom_bin2d(binwidth = c(3,1)) + scale_fill_gradient(high = 'red', low = 'blue')
pl2
# Out:
# plot without title

# %%
pl1 =  ggplot(movies, aes(x=year, y=rating))
pl2 = pl1 + geom_hex()
pl2
# Out:
# plot without title

# %% [markdown]
# # Coordinates and Faceting

# %%
pl = ggplot(mpg, aes(x=displ, y = hwy)) + geom_point()
pl2 = pl + coord_fixed(ratio = 1/8)
pl2
# Out:
# plot without title

# %%
pl = ggplot(mpg, aes(x=displ, y = hwy)) + geom_point()
pl2 = pl + facet_grid(drv ~ cyl)
pl2
# Out:
# plot without title

# %%
library(ggthemes)

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
#Histogram of hwy mpg values
pl1 = ggplot(mpg, aes(hwy))
pl2 = pl1 + geom_histogram(bins = 20, col = 'white', fill = 'red', alpha = 0.5 )
pl2
# Out:
# plot without title

# %%
#Barplot of car counts per manufacter with color filled by cyl count
pl1 = ggplot(mpg, aes(manufacturer))
pl2 = pl1 + geom_bar(aes(fill=factor(cyl))) + theme(axis.text.x = element_text(angle = 45, hjust = 1))
pl2
# Out:
# plot without title

# %%
head(txhousing)
# Out:
#   city    year month sales volume   median listings inventory date
# 1 Abilene 2000 1      72    5380000 71400  701      6.3       2000.000
# 2 Abilene 2000 2      98    6505000 58700  746      6.6       2000.083
# 3 Abilene 2000 3     130    9285000 58100  784      6.8       2000.167
# 4 Abilene 2000 4      98    9730000 68600  785      6.9       2000.250
# 5 Abilene 2000 5     141   10590000 67300  794      6.8       2000.333
# 6 Abilene 2000 6     156   13910000 66900  780      6.6       2000.417

# %%
#Scatter plot of volume vs. scales
pl = ggplot(txhousing, aes(x=sales, y = volume)) + geom_point(color = 'blue', alpha = 0.5)
pl
# Out:
# Warning message:
# “Removed 568 rows containing missing values (geom_point).”
# plot without title

# %%
# addsmooth line
pl + geom_smooth(color = 'red')
# Out:
# `geom_smooth()` using method = 'gam'
# Warning message:
# “Removed 568 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 568 rows containing missing values (geom_point).”
# plot without title
